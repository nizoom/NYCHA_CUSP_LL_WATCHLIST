# %%
# Adding Violations to NYCHA Addresses

# %%
import pandas as pd
from joblib import load

# %%
addresses_df = pd.read_csv("../processed_data/cleaned_fuzzy_matching.csv")
nycha_df = pd.read_csv("../data/nycha.csv")
borough_map = load('borough_map.joblib')

# %%
addresses_df.head()
# Out:
#    nycha_idx  hpd_inx                       nycha_address  \
# 0          0  3195153    1 LORRAINE STREET BROOKLYN 11231
# 1          3   778118  621 EAST 105 STREET BROOKLYN 11236
# 2         10    14153    1605 EAST 174 STREET BRONX 10472
# 3         12    65564  147 RICHARDS STREET BROOKLYN 11231
# 4         16   205173    1591 PARK AVENUE MANHATTAN 10029
#
#                           hpd_address       score
# 0    1 LORRAINE STREET BROOKLYN 11231  100.000000
# 1  621 EAST 102 STREET BROOKLYN 11236   97.058824
# 2    1670 EAST 174 STREET BRONX 10472   96.875000
# 3  179 RICHARDS STREET BROOKLYN 11231   97.058824
# 4    1351 PARK AVENUE MANHATTAN 10029   96.875000

# %%
nycha_df.head()
# Out:
#    Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0      18220152                       808768                        3
# 1      18220153                       808768                        3
# 2      18220154                       808768                        3
# 3      18223815                       286990                        3
# 4      18223816                       286990                        3
#
#   Primary Borough Name Primary House Number Primary Low House Number  \
# 0             BROOKLYN                    1                        1
# 1             BROOKLYN                    1                        1
# 2             BROOKLYN                    1                        1
# 3             BROOKLYN                  621                      615
# 4             BROOKLYN                  621                      615
#
#   Primary High House Number Primary Street Name  Primary Postcode  \
# ...

# %%
# for each address in addresses_df check datasets for all vios with that address 

# borough_map = {
#     "BROOKLYN": hpd_brooklyn['Full_Address'].tolist(),
#     "BRONX": hpd_bronx['Full_Address'].tolist(),
#     "MANHATTAN": hpd_manhattan['Full_Address'].tolist(),
#     "QUEENS": hpd_queens['Full_Address'].tolist(),
#     "STATEN ISLAND": hpd_si['Full_Address'].tolist()
# }

borough_map['BROOKLYN']
# Out:
# ['22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '118 FENIMORE STREET BROOKLYN 11225',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '1601 OCEAN PARKWAY BROOKLYN 11223',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
#  '22 FRONT STAGG STREET BROOKLYN 11206',
# ...
